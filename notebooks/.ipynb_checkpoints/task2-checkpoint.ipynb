# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing clean dataset for task 2
pd.set_option('max_column', None)
db = pd.read_csv('../data/task2_data.csv', na_values=['?', None])
db.head(2)
# Out:
#    MSISDN/Number  Number of sessions  Dur. (ms)  HTTP (Bytes)  \
# 0   3.360100e+10                   1   116720.0           0.0
# 1   3.360100e+10                   1   181230.0           0.0
#
#    Social Media (Bytes)  Google (Bytes)  Email (Bytes)  Youtube (Bytes)  \
# 0             2232135.0       4389005.0      1331362.0       21624548.0
# 1             2660565.0       5334863.0      3307781.0       12432223.0
#
#    Netflix (Bytes)  Gaming (Bytes)  Other (Bytes)  Total (Bytes)  \
# 0       27180981.0     812458661.0    386570872.0    878690574.0
# 1       11221763.0     119750078.0    281710071.0    156859643.0
#
#                      Handset Type Handset Manufacturer
# 0  Huawei P20 Lite Huawei Nova 3E               Huawei
# 1          Apple iPhone 7 (A1778)                Apple

# %%
db.describe()
# Out:
#        MSISDN/Number  Number of sessions     Dur. (ms)  HTTP (Bytes)  \
# count   1.064710e+05       106471.000000  1.064710e+05  1.064710e+05
# mean    4.515611e+10            1.380921  1.465715e+05  7.556774e+07
# std     2.894643e+12            0.777767  1.865627e+05  8.397500e+08
# min     3.360100e+10            1.000000  7.142000e+03  0.000000e+00
# 25%     3.365088e+10            1.000000  7.239950e+04  0.000000e+00
# 50%     3.366365e+10            1.000000  1.031370e+05  1.520000e+02
# 75%     3.368345e+10            2.000000  1.727990e+05  1.734976e+06
# max     8.823971e+14           18.000000  1.855375e+07  7.302069e+10
#
#        Social Media (Bytes)  Google (Bytes)  Email (Bytes)  Youtube (Bytes)  \
# count          1.064710e+05    1.064710e+05   1.064710e+05     1.064710e+05
# mean           2.549791e+06    1.089070e+07   3.151121e+06     3.158172e+07
# std            1.909685e+06    7.552384e+06   2.224563e+06     2.131551e+07
# min            1.563000e+03    4.033000e+04   1.817600e+04     7.890300e+04
# 25%            1.211936e+06    5.945632e+06   1.675398e+06     1.863663e+07
# 50%            2.305229e+06    9.592577e+06   2.801129e+06     2.681633e+07
# 75%            3.309043e+06    1.322318e+07   3.848998e+06     3.795666e+07
# max            4.337478e+07    1.521919e+08   4.241878e+07     4.529588e+08
#
#        Netflix (Bytes)  Gaming (Bytes)  Other (Bytes)  Total (Bytes)
# count     1.064710e+05    1.064710e+05   1.064710e+05   1.064710e+05
# mean      3.156318e+07    6.002585e+08   5.989493e+08   6.915199e+08
# std       2.130939e+07    4.495611e+08   4.492890e+08   4.915267e+08
# min       1.845690e+05    3.063580e+05   1.490450e+05   3.324901e+07
# 25%       1.857011e+07    2.882493e+08   2.858747e+08   3.587652e+08
# 50%       2.673116e+07    5.426773e+08   5.401097e+08   6.183269e+08
# 75%       3.800233e+07    7.777045e+08   7.756466e+08   8.578732e+08
# max       3.995191e+08    7.749432e+09   8.167878e+09   8.846226e+09

# %%
db.sort_values(by=['Number of sessions'], ascending=False)[:10]
# Out:
#        MSISDN/Number  Number of sessions   Dur. (ms)  HTTP (Bytes)  \
# 13467   3.362632e+10                  18   8791927.0     2048721.0
# 13123   3.362578e+10                  17  18553754.0      263236.0
# 6404    3.361489e+10                  17   9966898.0    75195150.0
# 36909   3.365973e+10                  16   4035428.0    34421844.0
# 76077   3.367588e+10                  15   4865947.0   109649231.0
# 92584   3.376054e+10                  15   9279434.0    36158295.0
# 64883   3.366716e+10                  13   8744914.0    25984556.0
# 92239   3.376041e+10                  12   5321667.0    57738303.0
# 36909      399519079.0    6.725559e+09   6.317415e+09   7.705863e+09
# 62804      214416926.0    6.646303e+09   4.349141e+09   7.308501e+09
# 92239      318347546.0    6.268620e+09   4.101645e+09   7.132371e+09
# 57032      251798809.0    6.103856e+09   3.976960e+09   6.872018e+09
# 86138      268247480.0    5.753743e+09   4.689876e+09   6.540899e+09
#
#                              Handset Type           Handset Manufacturer
# 6404          Samsung Galaxy J5 (Sm-J530)                        Samsung
# 92584         Samsung Galaxy J5 (Sm-J530)                        Samsung
# 13123            Samsung Galaxy A8 (2018)                        Samsung
# 13467         Samsung Galaxy J3 (Sm-J330)                        Samsung
# 76077                      Huawei Y7 2018                         Huawei
# 36909                          Huawei P20                         Huawei
# 62804            Samsung Galaxy A8 (2018)                        Samsung
# 92239         Apple iPhone 8 Plus (A1897)                          Apple
# 57032   Samsung Galaxy S9 Plus (Sm-G965F)                        Samsung
# 86138  Sony Mobile Comm. Xperia Xa2 Ultra  Sony Mobile Communications Ab

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(db['HTTP (Bytes)'], kde=True, color='blue')
plt.title(f'Distribution of Total (Bytes)', size=20, fontweight='bold')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(db['Dur. (ms)'], kde=True, color='blue')
plt.title(f'Distribution of Duration', size=20, fontweight='bold')
plt.show()

# %% [raw]
# Normalizing:

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()

# %%
column_names_to_normalize = ['Dur. (ms)','Number of sessions','Total (Bytes)']
X = db[column_names_to_normalize].values
x_scaled = normalizer.fit_transform(X, y =None)
db_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = db.index)
db[column_names_to_normalize] = db_temp

# %%
 db_temp.head()
# Out:
#    Dur. (ms)  Number of sessions  Total (Bytes)
# 0   0.000133        1.138057e-09       1.000000
# 1   0.001155        6.375122e-09       0.999999
# 2   0.000226        1.677947e-09       1.000000
# 3   0.000118        2.367869e-09       1.000000
# 4   0.000025        1.372297e-09       1.000000

# %% [raw]
# K-means Clustering:

# %%
#determining number of clusters with elbow method
X = db_temp.values
from sklearn.cluster import KMeans
#fitting kmeans to dataset
kmeans = KMeans(n_clusters=3, init= 'k-means++', n_init = 10, max_iter = 300, random_state= 0 )
Y_kmeans = kmeans.fit_predict(X)
# #visualizing clusters
# plt.scatter(X[Y_kmeans == 0,0], X[Y_kmeans==0,1 ], s = 100, c='red', label= 'cluster1')
# plt.scatter(X[Y_kmeans == 1,0], X[Y_kmeans==1,1 ], s = 100, c='cyan', label= 'cluster2')
# plt.scatter(X[Y_kmeans == 2,0], X[Y_kmeans==2,1 ], s = 100, c='green', label= 'cluster3')
# # plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], s =300, c='yellow', label = 'centroids')
# plt.title('Clusters')
# plt.legend()
# plt.show()
cluster_1 = pd.DataFrame(X[Y_kmeans == 0], columns=column_names_to_normalize)
cluster_2 = pd.DataFrame(X[Y_kmeans == 1], columns=column_names_to_normalize)
cluster_3 = pd.DataFrame(X[Y_kmeans == 2], columns=column_names_to_normalize)

# %%
cluster_1.describe()
# Out:
#           Dur. (ms)  Number of sessions  Total (Bytes)
# count  89187.000000        8.918700e+04   8.918700e+04
# mean       0.000179        2.231191e-09   1.000000e+00
# std        0.000106        1.390938e-09   2.311408e-08
# min        0.000008        2.835660e-10   9.999999e-01
# 25%        0.000099        1.405808e-09   1.000000e+00
# 50%        0.000162        1.821341e-09   1.000000e+00
# 75%        0.000246        2.523641e-09   1.000000e+00
# max        0.000453        2.171671e-08   1.000000e+00
